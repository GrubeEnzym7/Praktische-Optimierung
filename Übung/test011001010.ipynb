# %%
import random
import numpy as np

# %%
class Mutationen:
    def __init__(self):
        pass

    def two_swap_mutation(self, individual, K):
        size = len(individual)
        if size < 2:
            return individual # Keine Mutation möglich, wenn die Länge weniger als 2 ist

        for _ in range(K):  # Wähle zwei verschiedene Positionen zufällig aus
            pos1, pos2 = random.sample(range(size), 2)
            individual[pos1], individual[pos2] = individual[pos2], individual[pos1] # Tausch der Werte an den beiden Positionen

        return individual

    def one_translocation_mutation(self, individual, K):
        size = len(individual)
        for _ in range(K):  # Wähle eine zufällige Position für das Gen, das verschoben werden soll
            pos1 = random.randint(0, size - 1)
            gene = individual.pop(pos1)
            pos2 = random.randint(0, size - 1) # Wähle eine neue zufällige Position, um das Gen wieder einzufügen
            individual.insert(pos2, gene)
        return individual

    def mutate(self, individual, method, K):
        if method == '2-Swap':
            return self.two_swap_mutation(individual, K)
        elif method == '1-Translocation':
            return self.one_translocation_mutation(individual, K)
        else:
            raise ValueError("Invalid mutation method. Choose '2-Swap' or '1-Translocation'.")

# %%
class Rekombination:
    def __init__(self):
        pass

    def order_based_crossover(self, parent1, parent2):
        size = len(parent1)
        start, end = sorted(random.sample(range(size), 2))  # Wähle zwei zufällige Schnittpunkte
        #Initailisieren der Kinder
        child1 = [-1] * size
        child1[start:end] = parent1[start:end]
        #Aktuelle Indexposition 
        child1_pointer = end
        parent2_pointer = end
        #OBX für 1.Kind
        while -1 in child1:
            if parent2[parent2_pointer % size] not in child1: #Index Bsp [5 % 9]: Modulo Operator, hier 5<9 --> parent2[5] mit Kind verglichen
                child1[child1_pointer % size] = parent2[parent2_pointer % size] #Indexpositon des Kindes wird mit entsprechnden Eintrag des Eltern aufgefüllt
                child1_pointer += 1
            parent2_pointer += 1

        return child1

    def partially_mapped_crossover(self, parent1, parent2):
        size = len(parent1)
        start, end = sorted(random.sample(range(size), 2))
        child1 = [-1] * size
        child1[start:end] = parent1[start:end]

        mapping = {}
        for i in range(start, end):
            mapping[parent1[i]] = parent2[i]
            mapping[parent2[i]] = parent1[i]

        def fill_child(child, parent, start, end, mapping):
            for i in range(size):
                if i < start or i >= end:
                    gene = parent[i]
                    while gene in child[start:end]:
                        gene = mapping[gene]
                    child[i] = gene

        fill_child(child1, parent2, start, end, mapping)
        return child1

    def keine_rekombination(self, parent1, parent2): #Keine Rekombination --> Kinder sind gleich zu Eltern
        return parent1

    def recombine(self, parent1, parent2, method):
        if method == 'OBX':
            return self.order_based_crossover(parent1, parent2)
        elif method == 'PMX':
            return self.partially_mapped_crossover(parent1, parent2)
        elif method == 'NIX':
            return self.keine_rekombination(parent1, parent2)
        else:
            raise ValueError("Invalid recombination method. Choose 'OBX', 'PMX', or 'NIX'.")

# %%
class Zielfunktionen:
    def __init__(self):
        pass

    def ziel_1(self, kandidat): #Maximum - Minimum 
        sums = self.evaluate(kandidat)
        return max(sums) - min(sums)  

    def ziel_2(self, kandidat): #Summe der absoluten Differenz von allen Paaren
        sums = self.evaluate(kandidat)
        total_difference = 0
        for i in range(len(sums)):  #Sums enthält alle möglichen s1 bis s8 Elemente
            for j in range(i + 1, len(sums)):  #Durchläuft nachfolgendes Element nach i 
                total_difference += abs(sums[i] - sums[j])
        return total_difference

    def ziel_3(self, kandidat):  #Summe der absoluten Differenz von s1 und allen andern s2 bis s8
        sums = self.evaluate(kandidat)
        s1 = sums[0]
        total_difference = 0
        for i in range(1, len(sums)):
            total_difference += abs(s1 - sums[i])
        return total_difference

    def evaluate(self, kandidat):
        s1 = sum(kandidat[0:3])
        s2 = sum(kandidat[3:6])
        s3 = sum(kandidat[6:9])
        s4 = sum(kandidat[0:9:3])
        s5 = sum(kandidat[1:9:3])
        s6 = sum(kandidat[2:9:3])
        s7 = kandidat[0] + kandidat[4] + kandidat[8]
        s8 = kandidat[2] + kandidat[4] + kandidat[6]
        return [s1, s2, s3, s4, s5, s6, s7, s8]

# %%
class EvolutionaryAlgorithm:
    def __init__(self, mu, lamb, mutation_k, mutation_method, recombination_method, zielfunktion,max_evaluations=10000):  #Weil Probleme, versuch mit maximaler evaluations-Anzahl
        self.mu = mu #Eltern
        self.lamb = lamb #Kinder
        self.mutation_k = mutation_k #Für Mutationen k=2 oder k=4
        self.mutation_method = mutation_method #Mutationen
        self.mutationen = Mutationen()
        self.rekombination_method = recombination_method #Rekombinationen
        self.rekombination = Rekombination()
        self.zielfunktion = zielfunktion #Zielfunktion
        self.max_evaluations = max_evaluations  # Max Evaluations festgelegt
        self.population = [random.sample(range(1, 10), 9) for _ in range(mu)] #Erstellung von (mu)-Individuen (zufällige Zahl von 1 bis 9) einer zufälliger Population 


    def run(self):
        auswertungen = 0 #Anzahl der Auswertungen der Zielfunktion
        while auswertungen < self.max_evaluations:
            offspring = []
            for _ in range(self.lamb): #Schleife für Kinder
                parent1, parent2 = random.sample(self.population, 2)
                child = self.rekombination.recombine(parent1, parent2, self.rekombination_method) #Rekombination
                child = self.mutationen.mutate(child, self.mutation_method, self.mutation_k) #Mutation
                offspring.append(child)
                auswertungen += 1
            self.population += offspring
            self.population.sort(key=self.zielfunktion) #Sortierung nach Zielfunktion
            self.population = self.population[:self.mu]   #Auswahl bester Individuen

            if self.is_magic_square(self.population[0]):
                return auswertungen

    def is_magic_square(self, kandidat): #Überprüfen ob magischer Würfel passt
        return self.zielfunktion(kandidat) == 0 #Zielfunktion ist gleich 0 für magischen Würfel

if __name__ == "__main__":
    mu_values = [5, 10, 20]
    lambda_values = [1, 5, 10]
    mutation_operators = ['2-Swap', '1-Translocation']
    mutation_k_werte = [2, 4]
    rekombination_operators = ['OBX', 'PMX', 'NIX']
    zielfunktionen = Zielfunktionen()
    zielfunktion_operators = [zielfunktionen.ziel_1, zielfunktionen.ziel_2, zielfunktionen.ziel_3]

    results = []

    for mu in mu_values: #Durch Eltern
        for lamb in lambda_values: #Durch Kinder
            for mutation_operator in mutation_operators: #Durch Mutationen
                for mutation_k in mutation_k_werte: #Mutationswert k=2 oder k=4
                    for rekombination_operator in rekombination_operators: #Durch Rekombinationen
                        for zielfunktion_operator in zielfunktion_operators: #Durch Zielfunktionen
                            for _ in range(100): #100-Wiederholungen
                                ea = EvolutionaryAlgorithm(mu, lamb, mutation_k, mutation_operator, rekombination_operator, zielfunktion_operator)
                                evaluations = ea.run()
                                results.append({
                                    'Evaluations': evaluations,
                                    'Mu': mu,
                                    'Lambda': lamb,
                                    'Mutation': mutation_operator,
                                    'Mutation K': mutation_k,
                                    'Rekombination': rekombination_operator,
                                    'Zielfunktion': zielfunktion_operator.__name__
                                })
                                print(f"Evaluations: {evaluations}, Mu: {mu}, Lambda: {lamb}, Mutation: {mutation_operator}, Mutation K: {mutation_k}, Rekombination: {rekombination_operator}, Zielfunktion: {zielfunktion_operator.__name__}")

    for result in results:
        print(result)
# Out:
# Evaluations: 784, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1364, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1903, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1642, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4661, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2212, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3474, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 462, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 579, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 963, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3217, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 307, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4628, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 575, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 585, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1013, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1563, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 441, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 950, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 382, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 6095, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1939, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4230, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 801, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 49, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2025, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1337, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1556, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1636, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 631, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1101, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1368, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2623, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1365, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 541, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2221, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 446, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2052, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1410, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 315, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4388, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3850, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2028, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1652, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 7919, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 6400, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 5402, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3440, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3908, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 968, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2276, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 761, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4138, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1907, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 5203, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4253, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1360, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3441, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 245, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4195, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1088, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3773, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2438, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1616, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 5869, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 5766, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 5243, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1977, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 665, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1709, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 369, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 288, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2771, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 967, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 995, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2169, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1196, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4177, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 6110, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 2406, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 628, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 175, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 4562, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1002, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 3334, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1680, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_1
# Evaluations: 1169, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1585, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 172, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 848, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1203, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 293, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1850, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 408, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 635, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 932, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 597, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1488, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 978, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 361, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 750, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2248, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2551, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 492, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1611, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1490, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1418, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 301, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 588, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1128, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1231, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1945, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2071, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1172, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 428, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1700, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2059, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2928, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1352, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 804, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 358, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 510, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 988, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1796, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 524, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 84, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2455, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 219, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1470, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1828, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 756, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2078, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 181, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 653, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 973, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 377, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 862, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2144, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1112, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 830, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 5174, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 585, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 358, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 677, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2442, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 3163, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1111, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 340, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2656, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1221, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1656, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 699, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 2576, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 3273, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 924, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 1824, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 3455, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_2
# Evaluations: 865, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 4972, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 2019, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 221, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1070, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 353, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1654, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 635, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1897, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1565, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 653, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 4169, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 2913, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1829, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1146, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1323, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1759, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 7379, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 3059, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1077, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1144, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1347, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1787, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 791, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1117, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 3105, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1519, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 811, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 2192, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 465, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 548, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1903, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1493, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 977, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1742, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 2207, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 646, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 886, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 435, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 9236, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 2576, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1328, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1572, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 3972, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 5155, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 997, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 761, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 596, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 323, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 244, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 3026, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 141, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 3713, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 801, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: None, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1109, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# Evaluations: 1160, Mu: 5, Lambda: 1, Mutation: 2-Swap, Mutation K: 2, Rekombination: OBX, Zielfunktion: ziel_3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 54
#      52 for _ in range(100): #100-Wiederholungen
#      53     ea = EvolutionaryAlgorithm(mu, lamb, mutation_k, mutation_operator, rekombination_operator, zielfunktion_operator)
# ---> 54     evaluations = ea.run()
#      55     results.append({
#      56         'Evaluations': evaluations,
#      57         'Mu': mu,
#    (...)
#      62         'Zielfunktion': zielfunktion_operator.__name__
#      63     })
#      64     print(f"Evaluations: {evaluations}, Mu: {mu}, Lambda: {lamb}, Mutation: {mutation_operator}, Mutation K: {mutation_k}, Rekombination: {rekombination_operator}, Zielfunktion: {zielfunktion_operator.__name__}")
#
# Cell In[17], line 21, in EvolutionaryAlgorithm.run(self)
#      19 for _ in range(self.lamb): #Schleife für Kinder
#      20     parent1, parent2 = random.sample(self.population, 2)
# ---> 21     child = self.rekombination.recombine(parent1, parent2, self.rekombination_method) #Rekombination
#      22     child = self.mutationen.mutate(child, self.mutation_method, self.mutation_k) #Mutation
#      23     offspring.append(child)
#
# Cell In[12], line 52, in Rekombination.recombine(self, parent1, parent2, method)
#      50     return self.order_based_crossover(parent1, parent2)
#      51 elif method == 'PMX':
# ---> 52     return self.partially_mapped_crossover(parent1, parent2)
#      53 elif method == 'NIX':
#      54     return self.keine_rekombination(parent1, parent2)
#
# Cell In[12], line 42, in Rekombination.partially_mapped_crossover(self, parent1, parent2)
#      39                 gene = mapping[gene]
#      40             child[i] = gene
# ---> 42 fill_child(child1, parent2, start, end, mapping)
#      43 return child1
#
# Cell In[12], line 38, in Rekombination.partially_mapped_crossover.<locals>.fill_child(child, parent, start, end, mapping)
#      36 if i < start or i >= end:
#      37     gene = parent[i]
# ---> 38     while gene in child[start:end]:
#      39         gene = mapping[gene]
#      40     child[i] = gene
#
# KeyboardInterrupt:
